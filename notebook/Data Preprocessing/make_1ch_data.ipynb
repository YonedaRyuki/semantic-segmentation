# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import shutil
import glob

# %%
img = Image.open('/home/filament/Downloads/semantic_segmentation/data/VOCdevkit/VOC2012/filament_orionKL_datasets (1)/orionKL_4 (1).jpg')
imgGray = img.convert('L')
# array = np.asarray(imgGray,np.uint8)
# print(array.shape)
imgGray.save('/home/filament/Downloads/itijitekinayatu/orionKL_4 (1).jpg')

# %%
plt.imshow(imgGray)

# %%
img_arr = np.array(img.convert("L"))

# %%
img_arr = Image.fromarray(img_arr)
img_arr
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7FD9C07754D0>

# %%
img_ = Image.open('/home/filament/Downloads/itijitekinayatu/orionKL_18.jpg')
plt.imshow(img)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=576x576 at 0x7F414EB1ABD0>

# %%
file = glob.glob("/home/filament/Downloads/semantic_segmentation/data/VOCdevkit/VOC2012/filament_orionKL_datasets/*.jpg")

# %%
for i in file:
    img = Image.open(i)
    arr = np.array(img)
    print(arr.shape)
# Out:
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
# (576, 576, 3)
