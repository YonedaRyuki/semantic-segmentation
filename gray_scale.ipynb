# %%
from PIL import Image

img = Image.open('/content/drive/MyDrive/3_semantic_segmentation/data/VOCdevkit/VOC2012/cat_JPEGImages/2007_000528.jpg')
imgGray = img.convert('L')
# imgGray.save('/content/drive/MyDrive/3_semantic_segmentation/data/VOCdevkit/VOC2012/gray_cat_JPEGImages')

# %%
imgGray.save('/content/drive/MyDrive/3_semantic_segmentation/data/VOCdevkit/VOC2012/gray_cat_JPEGImages/2007_000528.jpg')

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import shutil
import glob

# %%
files = glob.glob('/content/drive/MyDrive/3_semantic_segmentation/data/VOCdevkit/VOC2012/cat_JPEGImages/*.jpg')
for file in files:
  file = file.split('/')
  file = file[9]
  img = Image.open('/content/drive/MyDrive/3_semantic_segmentation/data/VOCdevkit/VOC2012/cat_JPEGImages/'+ str(file))
  imgGray = img.convert('L').convert('RGB')
  imgGray.save('/content/drive/MyDrive/3_semantic_segmentation/data/VOCdevkit/VOC2012/gray_cat_3ch_JPEGImages/'+ str(file))

# %%
a = a.split('/')
a[9]
# Out:
# '2007_009724.jpg'

# %%
len(files)
# Out:
# 845

# %%
files = glob.glob('/content/drive/MyDrive/3_semantic_segmentation/data/VOCdevkit/VOC2012/gray_cat_JPEGImages/*.jpg')

# %%
len(files)
# Out:
# 845

# %%
from PIL import Image

img = Image.open('/content/drive/MyDrive/3_semantic_segmentation/data/cowboy-757575_640.jpg')
imgGray = img.convert('L')
# array = np.asarray(imgGray,np.uint8)
# print(array.shape)
imgGray.save('/content/drive/MyDrive/cat_datasets/cowboy_gray.jpeg')
